# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.multiclass import OneVsRestClassifier

# %%
df = pd.read_csv('Book1.csv', index_col=0)
df.head()
# Out:
#                                                 Text                Tags
# 2  aspnet site maps has anyone got experience cre...  ['sql', 'asp.net']
# 4  adding scripting functionality to net applicat...      ['c#', '.net']
# 5  should i use nested classes in this case i am ...             ['c++']
# 6  homegrown consumption of web services i have b...            ['.net']
# 8  automatically update version number i would li...              ['c#']

# %%
import ast
df['Tags'] = df['Tags'].apply(lambda x: ast.literal_eval(x))

# %%
df.head()
# Out:
#                                                 Text            Tags
# 2  aspnet site maps has anyone got experience cre...  [sql, asp.net]
# 4  adding scripting functionality to net applicat...      [c#, .net]
# 5  should i use nested classes in this case i am ...           [c++]
# 6  homegrown consumption of web services i have b...          [.net]
# 8  automatically update version number i would li...            [c#]

# %%
df['Tags'] = df['Tags'].apply(lambda x: " ".join(x))

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i))

    return " ".join(y)

# %%
df['Text'] = df['Text'].apply(stem)

# %%
df['Tags']
# Out:
# 2               sql asp.net
# 4                   c# .net
# 5                       c++
# 6                      .net
# 8                        c#
#                 ...
# 186100               python
# 186108        ruby-on-rails
# 186110    javascript jquery
# 186126                  php
# 186131               jquery
# Name: Tags, Length: 21047, dtype: object

# %%
df['Text'][2]
# Out:
# 'aspnet site map ha anyon got experi creat sqlbase aspnet sitemap providersi have got the default xml file websitemap work properli with my menu and sitemappath control but i will need a way for the user of my site to creat and modifi page dynamicallyi need to tie page view permiss into the standard aspnet membership system as well'

# %%
df['Text'][4]
# Out:
# 'ad script function to net applic i have a littl game written in c it use a databas as backend it is a trade card game and i want to implement the function of the card as a scriptwhat i mean is that i essenti have an interfac icard which a card class implement public class card056 icard and which contain function that are call by the gamenow to make the thing maintainablemodd i would like to have the class for each card as sourc code in the databas and essenti compil it on first use so when i have to addchang a card i will just add it to the databas and tell my applic to refresh without need ani assembl deploy especi sinc we would be talk about 1 assembl per card which mean hundr of assembliesi that possibl regist a class from a sourc file and then instanti it etcicard cardscurr new mygamecardlibrarycard056cardscurrentonenterplayref currentgamestateth languag is c but extra bonu if it is possibl to write the script in ani net languag'

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(df['Text']).toarray()

# %%
vector.shape
# Out:
# (21047, 5000)

# %%
cv.get_feature_names()
# Out:
# ['00',
#  '00f',
#  '01',
#  '010',
#  '0126',
#  '02',
#  '03',
#  '030',
#  '04',
#  '05',
#  '0523',
#  '0526',
#  '06',
#  '07',
#  '08',
#  '09',
#  '092704',
#  '0949',
#  '0class',
#  '0i',
#  '0int',
#  '0px',
#  '0s',
#  '0the',
#  '0thi',
#  '0what',
#  '0x0',
#  '0x02ab43f0',
#  '0x10',
#  '0xf',
#  '0xff',
#  '10',
#  '100',
#  '100k',
#  '100px',
#  '101',
#  '1010',
#  '101823139',
#  '102',
#  '1024',
#  '103720682',
#  '104',
#  '105',
#  '106',
#  '10f',
#  '10i',
#  '10px',
#  '11',
#  '110',
#  '112',
#  '113007',
#  '113448644',
#  '116',
#  '12',
#  '120',
#  '121',
#  '123',
#  '1234',
#  '127',
#  '127001',
#  '128',
#  '13',
#  '130',
#  '132',
#  '133710507',
#  '133710508',
#  '133710509',
#  '133710510',
#  '133710511',
#  '133710512',
#  '133710513',
#  '133710514',
#  '133710515',
#  '133833996',
#  '133856841',
#  '133906901',
#  '14',
#  '1400',
#  '142',
#  '15',
#  '150',
#  '152917803',
#  '159',
#  '16',
#  '160',
#  '162539360',
#  '16bit',
#  '17',
#  '1732819',
#  '18',
#  '180',
#  '187',
#  '19',
#  '192',
#  '1a',
#  '1i',
#  '1px',
#  '1s',
#  '1st',
#  '20',
#  '200',
#  '2003',
#  '2005',
#  '2007',
#  '2008',
#  '2009',
#  '200px',
#  '201',
#  '2010',
#  '2011',
#  '20110113',
#  '20110701',
#  '205545861',
#  '20px',
#  '21',
#  '212',
#  '22',
#  '221719895',
#  '23',
#  '235',
#  '24',
#  '244',
#  '25',
#  '250',
#  '255',
#  '256',
#  '26',
#  '27',
#  '271',
#  '2755',
#  '28',
#  '29',
#  '2a',
#  '2d',
#  '2i',
#  '2nd',
#  '2px',
#  '2x',
#  '30',
#  '300',
#  '301',
#  '303',
#  '308',
#  '31',
#  '317',
#  '32',
#  '320',
#  '32bit',
#  '33',
#  '34',
#  '35',
#  '36',
#  '37',
#  '38',
#  '39',
#  '3d',
#  '3g',
#  '3i',
#  '3px',
#  '3rd',
#  '3x',
#  '40',
#  '400',
#  '401',
#  '404',
#  '41',
#  '42',
#  '43',
#  '44',
#  '45',
#  '46',
#  '47',
#  '48',
#  '480',
#  '49',
#  '4gb',
#  '4i',
#  '4th',
#  '50',
#  '500',
#  '500px',
#  '501',
#  '51',
#  '52',
#  '53',
#  '54',
#  '55',
#  '56',
#  '57',
#  '59',
#  '5px',
#  '5th',
#  '60',
#  '600',
#  '61',
#  '62',
#  '63',
#  '64',
#  '64bit',
#  '65',
#  '67',
#  '68',
#  '69',
#  '70',
#  '72',
#  '75',
#  '76',
#  '78',
#  '80',
#  '800',
#  '84',
#  '853',
#  '86',
#  '89',
#  '8bit',
#  '90',
#  '91',
#  '93',
#  '95',
#  '98',
#  '99',
#  'a0',
#  'a1',
#  'a2',
#  'a3',
#  'a4',
#  'aa',
#  'ab',
#  'abandon',
#  'abbrevi',
#  'abc',
#  'abcd',
#  'abil',
#  'abl',
#  'abort',
#  'abov',
#  'absolut',
#  'abstract',
#  'ac',
#  'academ',
#  'acc',
#  'acceler',
#  'accent',
#  'accept',
#  'access',
#  'accessor',
#  'accident',
#  'accod',
#  'accompanyid',
#  'accomplish',
#  'accord',
#  'accordingli',
#  'accordion',
#  'account',
#  'accur',
#  'accuraci',
#  'achiev',
#  'acinvno',
#  'acl',
#  'aclass',
#  'acquir',
#  'acronym',
#  'act',
#  'action',
#  'actionlisten',
#  'actionmail',
#  'actionperformedactionev',
#  'actionresult',
#  'activ',
#  'activerecord',
#  'activerecordbas',
#  'activesupport',
#  'activex',
#  'actor',
#  'actual',
#  'ad',
#  'adapt',
#  'adb',
#  'add',
#  'addin',
#  'addit',
#  'addon',
#  'addpreferredgaplayoutstylerel',
#  'addr',
#  'addremov',
#  'address',
#  'addrreturn',
#  'adipisc',
#  'adjac',
#  'adjust',
#  'admin',
#  'administr',
#  'admit',
#  'adob',
#  'adonet',
#  'adopt',
#  'adress',
#  'advanc',
#  'advanceedit',
#  'advantag',
#  'advertis',
#  'advic',
#  'advis',
#  'ae',
#  'afaik',
#  'affect',
#  'afraid',
#  'afterward',
#  'age',
#  'agenc',
#  'agent',
#  'aggreg',
#  'agnost',
#  'ago',
#  'agre',
#  'ahead',
#  'ahov',
#  'ai',
#  'aid',
#  'aim',
#  'aint',
#  'aio',
#  'air',
#  'ajax',
#  'aka',
#  'al',
#  'ala',
#  'alarm',
#  'alarmmanag',
#  'album',
#  'alert',
#  'alertdialog',
#  'algorithm',
#  'ali',
#  'alia',
#  'alias',
#  'align',
#  'alignleft',
#  'alignright',
#  'aliv',
#  'alli',
#  'alloc',
#  'allow',
#  'almostint',
#  'alon',
#  'alot',
#  'alpha',
#  'alphabet',
#  'alreadi',
#  'alright',
#  'alt',
#  'alter',
#  'altern',
#  'altogeth',
#  'alway',
#  'amaz',
#  'amazon',
#  'ambigu',
#  'amet',
#  'ami',
#  'ampersand',
#  'analog',
#  'analys',
#  'analysi',
#  'analyt',
#  'analyz',
#  'ancestor',
#  'anchor',
#  'andor',
#  'android',
#  'androidgravitycent',
#  'androidi',
#  'androidlayout',
#  'androidmanifestxml',
#  'androidorientationhorizont',
#  'androidorientationvert',
#  'androidst',
#  'androidtextcolorf',
#  'angl',
#  'ani',
#  'anim',
#  'animatedy',
#  'annot',
#  'announc',
#  'annoy',
#  'anonym',
#  'anoth',
#  'ansi',
#  'answer',
#  'ant',
#  'antialias',
#  'anticip',
#  'antlr',
#  'anybodi',
#  'anymor',
#  'anyon',
#  'anyth',
#  'anywher',
#  'aop',
#  'apach',
#  'apart',
#  'apc',
#  'api',
#  'apii',
#  'apk',
#  'apolog',
#  'app',
#  'appar',
#  'appbundlegemsruby191gemsactivesupport301libact',
#  'appconfig',
#  'appdeleg',
#  'appdomain',
#  'appear',
#  'append',
#  'appengin',
#  'appi',
#  'appkit',
#  'appl',
#  'applet',
#  'appli',
#  'applic',
#  'applicationcontextxml',
#  'applicationcontrol',
#  'applicationi',
#  'applicationjson',
#  'applicationth',
#  'appoint',
#  'appreci',
#  'appreciatedthank',
#  'approach',
#  'appropri',
#  'approx',
#  'approxim',
#  'appset',
#  'appweb1',
#  'apr',
#  'aptget',
#  'apubl',
#  'ar',
#  'arbitrari',
#  'arch',
#  'architectur',
#  'archiv',
#  'arduino',
#  'area',
#  'arg',
#  'arg0',
#  'arg1',
#  'arg2',
#  'arg3',
#  'argc',
#  'argument',
#  'argumentexcept',
#  'argv',
#  'arial',
#  'aris',
#  'arithmet',
#  'arm',
#  'armv7',
#  'arr',
#  'arrang',
#  'array',
#  'array1',
#  'arrayi',
#  'arraylist',
#  'arrayliststr',
#  'arriv',
#  'arrow',
#  'art',
#  'articl',
#  'artifact',
#  'artist',
#  'asc',
#  'ascend',
#  'ascii',
#  'asid',
#  'asihttprequest',
#  'asihttprequesto',
#  'ask',
#  'asm',
#  'asmx',
#  'asp',
#  'aspect',
#  'aspectj',
#  'asplabel',
#  'aspnet',
#  'aspx',
#  'assembl',
#  'assert',
#  'asset',
#  'assign',
#  'assist',
#  'associ',
#  'assum',
#  'assumpt',
#  'assur',
#  'ast',
#  'astr',
#  'async',
#  'asynchron',
#  'asynctask',
#  'atom',
#  'attach',
#  'attack',
#  'attempt',
#  'attend',
#  'attent',
#  'attr',
#  'attribut',
#  'audio',
#  'audit',
#  'aug',
#  'auth',
#  'authent',
#  'author',
#  'auto',
#  'autocomplet',
#  'autogener',
#  'autoincr',
#  'autoload',
#  'autom',
#  'automat',
#  'autoreleas',
#  'autothiscov',
#  'autowir',
#  'avail',
#  'averag',
#  'avg',
#  'avoid',
#  'aw',
#  'awar',
#  'away',
#  'awesom',
#  'awkward',
#  'ax',
#  'axi',
#  'az',
#  'azur',
#  'b1',
#  'b2',
#  'b3',
#  'ba',
#  'backbon',
#  'backbonej',
#  'backend',
#  'background',
#  'backgroundcolor',
#  'backgroundi',
#  'backgroundimag',
#  'backgroundposit',
#  'backgroundwork',
#  'backslash',
#  'backspac',
#  'backtrac',
#  'backup',
#  'backward',
#  'bad',
#  'badg',
#  'badli',
#  'balanc',
#  'ball',
#  'banana',
#  'band',
#  'bang',
#  'bank',
#  'bar',
#  'barcod',
#  'bare',
#  'barrier',
#  'base',
#  'base64',
#  'baseclass',
#  'bash',
#  'basi',
#  'basic',
#  'bat',
#  'batch',
#  'batteri',
#  'baz',
#  'bb',
#  'bc',
#  'bean',
#  'bear',
#  'beat',
#  'beauti',
#  'beautifulsoup',
#  'becam',
#  'becaus',
#  'becom',
#  'befor',
#  'began',
#  'begin',
#  'beginn',
#  'behav',
#  'behavior',
#  'behaviour',
#  'believ',
#  'belong',
#  'belowi',
#  'benchmark',
#  'beneath',
#  'benefit',
#  'besid',
#  'best',
#  'bestpractic',
#  'bet',
#  'beta',
#  'better',
#  'bi',
#  'bidirect',
#  'big',
#  'bigdecim',
#  'bigger',
#  'biggest',
#  'bigint',
#  'bigint20',
#  'biginteg',
#  'bin',
#  'binari',
#  'bind',
#  'binder',
#  'bindingsourc',
#  'birth',
#  'bit',
#  'bitmap',
#  'bitwis',
#  'bla',
#  'black',
#  'blackberri',
#  'blah',
#  'blank',
#  'blanktru',
#  'blend',
#  'blind',
#  'bloat',
#  'blob',
#  'block',
#  'blog',
#  'blow',
#  'blue',
#  'bluetooth',
#  'blur',
#  'bm',
#  'bmp',
#  'board',
#  'bob',
#  'bodi',
#  'bogu',
#  'boil',
#  'boilerpl',
#  'bold',
#  'bom',
#  'bonu',
#  'boo',
#  'book',
#  'bookmark',
#  'bool',
#  'boolean',
#  'boost',
#  'boostshar',
#  'boot',
#  'bootstrap',
#  'border',
#  'border0',
#  'borderbottom',
#  'borderradiu',
#  'bore',
#  'boss',
#  'bot',
#  'bother',
#  'bottleneck',
#  'bounc',
#  'bound',
#  'boundari',
#  'bounti',
#  'box',
#  'boxshadow',
#  'br',
#  'brace',
#  'bracket',
#  'brain',
#  'branch',
#  'brand',
#  'break',
#  'breakpoint',
#  'bridg',
#  'brief',
#  'briefli',
#  'bright',
#  'bring',
#  'broadcast',
#  'broadcastreceiv',
#  'broken',
#  'broker',
#  'brought',
#  'brows',
#  'browser',
#  'brush',
#  'bs',
#  'btree',
#  'btw',
#  'bu',
#  'bubbl',
#  'bucket',
#  'buf',
#  'buffer',
#  'bufferedimag',
#  'bufferedread',
#  'bufferedreadernew',
#  'buffers',
#  'bug',
#  'buggi',
#  'build',
#  'builder',
#  'buildout',
#  'buildxml',
#  'built',
#  'builtin',
#  'bulk',
#  'bullet',
#  'bump',
#  'bunch',
#  'bundl',
#  'busi',
#  'button',
#  'button1',
#  'buy',
#  'bypass',
#  'byte',
#  'bytebuff',
#  'bytecod',
#  'bytesread',
#  'c0x',
#  'c1',
#  'c11',
#  'c2',
#  'c3',
#  'c99',
#  'ca',
#  'cach',
#  'cachecontrol',
#  'cake',
#  'cakephp',
#  'calay',
#  'calcul',
#  'calendar',
#  'callabl',
#  'callback',
#  'calledi',
#  'caller',
#  'came',
#  'camera',
#  'canat',
#  'cancel',
#  'candid',
#  'canon',
#  'canva',
#  'cap',
#  'capabl',
#  'capac',
#  'capit',
#  'caption',
#  'captur',
#  'car',
#  'card',
#  'care',
#  'caret',
#  'carousel',
#  'carri',
#  'carriag',
#  'cart',
#  'cascad',
#  'case',
#  'casei',
#  'cassandra',
#  'cast',
#  'castl',
#  'cat',
#  'catch',
#  'catchexcept',
#  'categori',
#  'categoryid',
#  'caught',
#  'caus',
#  'cb',
#  'cbc',
#  'cc',
#  'cca9oelqo',
#  'ccli',
#  'ccode',
#  'ccompid',
#  'cd',
#  'cdata',
#  'cdef',
#  'cdn',
#  'cdocument',
#  'cdt',
#  'ce',
#  'celeri',
#  'cell',
#  'cellspacing0',
#  'center',
#  'cento',
#  'central',
#  'cert',
#  'certain',
#  'certainli',
#  'certif',
#  'cgcontextref',
#  'cgfloat',
#  'cgi',
#  'cgimag',
#  'cgimageref',
#  'cgpoint',
#  'cgrect',
#  'cgrectmake0',
#  'ch',
#  'chain',
#  'challeng',
#  'chanc',
#  'chang',
#  'channel',
#  'chapter',
#  'char',
#  'charact',
#  'charg',
#  'charset',
#  'charsetutf8',
#  'chart',
#  'chat',
#  'cheap',
#  'check',
#  'checkbox',
#  'checker',
#  'checkout',
#  'checkstyl',
#  'checksum',
#  'cheer',
#  'child',
#  'children',
#  'chines',
#  'choic',
#  'choos',
#  'chooser',
#  'chose',
#  'chosen',
#  'chrome',
#  'chunk',
#  'ci',
#  'cid',
#  'cil',
#  'cin',
#  'cipher',
#  'circl',
#  'circular',
#  'circumst',
#  'citi',
#  'ckeditor',
#  'cl',
#  'cla',
#  'claim',
#  'clang',
#  'clarif',
#  'clarifi',
#  'clariti',
#  'clash',
#  'claskinnycolumn',
#  'class',
#  'class1',
#  'class2',
#  'classa',
#  'classb',
#  'classclass',
#  'classi',
#  'classic',
#  'classitem',
#  'classload',
#  'classmethod',
#  'classnam',
#  'classpath',
#  'classpubl',
#  'claus',
#  'clean',
#  'cleaner',
#  'cleanest',
#  'cleanup',
#  'clear',
#  'clearer',
#  'clearli',
#  'clever',
#  'cli',
#  'click',
#  'clickabl',
#  'clickobject',
#  'clickonc',
#  'client',
#  'clientserv',
#  'clientsid',
#  'clip',
#  'clipboard',
#  'clock',
#  'clojur',
#  'clone',
#  'close',
#  'closer',
#  'closest',
#  'closur',
#  'cloud',
#  'clr',
#  'clue',
#  'cluster',
#  'clutter',
#  'cm',
#  'cmake',
#  'cmd',
#  'cn',
#  'cname',
#  'cnet',
#  'cnt',
#  'cocoa',
#  'cocos2d',
#  'code',
#  'codea',
#  'codebas',
#  'codebehind',
#  'codec',
#  'codeclass',
#  'codei',
#  'codeif',
#  'codeignit',
#  'codeimport',
#  'codeinclud',
#  'codepriv',
#  'codepubl',
#  'coder',
#  'codeth',
#  'codethank',
#  'codeus',
#  'codevar',
#  'coffeescript',
#  'col',
#  'col1',
#  'col2',
#  'collaps',
#  'collat',
#  'colleagu',
#  'collect',
#  'collector',
#  'collis',
#  'colon',
#  'color',
#  'colorspac',
#  'colour',
#  'column',
#  'columndefinit',
#  'columnnam',
#  'columnperson',
#  'com',
#  'combin',
#  'combo',
#  'combobox',
#  'come',
#  'comfort',
#  'comma',
#  'command',
#  'commandlin',
#  'comment',
#  'commerci',
#  'commiss',
#  'commit',
#  'common',
#  'commonli',
#  'commun',
#  'compact',
#  'compani',
#  'companyid',
#  'compar',
#  'compareto',
#  'comparison',
#  'compat',
#  'compil',
#  'compiletim',
#  'complain',
#  'complaint',
#  'complet',
#  'complex',
#  'compliant',
#  'complic',
#  'compon',
#  'compos',
#  'composit',
#  'comprehens',
#  'compress',
#  'comput',
#  'comrobosoftlinuxtop',
#  'concat',
#  'concaten',
#  'concept',
#  'conceptu',
#  'concern',
#  ...]

# %%
df['Text'].shape
# Out:
# (21047,)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.035007  , 0.01992048, ..., 0.        , 0.14147911,
#         0.08219949],
#        [0.035007  , 1.        , 0.34588866, ..., 0.0285831 , 0.22641187,
#         0.09208185],
#        [0.01992048, 0.34588866, 1.        , ..., 0.03659625, 0.43482828,
#         0.13754606],
#        ...,
#        [0.        , 0.0285831 , 0.03659625, ..., 1.        , 0.        ,
#         0.0503367 ],
#        [0.14147911, 0.22641187, 0.43482828, ..., 0.        , 1.        ,
#         0.02658174],
#        [0.08219949, 0.09208185, 0.13754606, ..., 0.0503367 , 0.02658174,
#         1.        ]])

# %%
df[df['Tags'] == 'sql asp.net']
# Out:
#                                                 Text         Tags
# 2  aspnet site map ha anyon got experi creat sqlb...  sql asp.net

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                                     Text               Tags
# 0      aspnet site map ha anyon got experi creat sqlb...        sql asp.net
# 1      ad script function to net applic i have a litt...            c# .net
# 2      should i use nest class in thi case i am work ...                c++
# 3      homegrown consumpt of web servic i have been w...               .net
# 4      automat updat version number i would like the ...                 c#
# ...                                                  ...                ...
# 21042  use python subprocess call to invok python scr...             python
# 21043  rail 3 activerecord api build method i am fair...      ruby-on-rails
# 21044  how to move an entir div element up x pixel i ...  javascript jquery
# 21045  get class name from file i have a php file whi...                php
# 21046  backbonej with aspnet mvc in the last few day ...             jquery
#
# [21047 rows x 2 columns]

# %%
def recommend(Tag):
    y=[]
    index = df[df['Tags'] == Tag].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:10]:
        if df.iloc[i[0]].Tags not in (df.iloc[i[0]].Tags).split():
            y.append(df.iloc[i[0]].Tags)
    l = list(set(y))
    x = " ".join(l)
    k = x.split()
    if Tag not in set(k):
            print(Tag)
    for i in set(k):
        print(i)

# %%
recommend('python')
# Out:
# ruby
# python
# java

# %%
df['Tags'].unique()
# Out:
# array(['sql asp.net', 'c# .net', 'c++', '.net', 'c#', 'c# asp.net', 'sql',
#        'html', 'c', 'asp.net', 'php mysql', 'ruby', 'java', 'php',
#        'sql mysql', 'javascript', 'css', 'objective-c', '.net sql',
#        'java .net', 'c++ python', 'java php', 'mysql', 'c++ c', 'python',
#        'ruby-on-rails', 'c# sql', '.net asp.net', 'html css',
#        'ruby-on-rails ruby', 'jquery', 'android', 'javascript html css',
#        'php html', 'asp.net css', 'javascript jquery',
#        'javascript python', 'c# java', 'iphone', 'asp.net .net',
#        'css html', 'c# asp.net javascript', 'c# c++', '.net html',
#        'php javascript', 'java javascript',
#        'javascript iphone objective-c', 'asp.net javascript html',
#        'javascript html', 'c# java python ruby', 'c# asp.net css',
#        'c# java python', 'javascript jquery html',
#        'c# c++ iphone objective-c', 'asp.net jquery', 'javascript iphone',
#        'c# .net sql', 'java ruby-on-rails', 'sql ruby-on-rails',
#        'java mysql', 'c# .net asp.net', 'c# java c++', 'c++ python c',
#        'java android', 'java c++ c', 'jquery asp.net', 'java ruby',
#        'iphone objective-c', 'python ruby', 'javascript jquery html css',
#        'jquery html', 'asp.net html', 'iphone html',
#        'asp.net javascript jquery', '.net c++ c',
#        'javascript ruby-on-rails', 'iphone objective-c ruby',
#        'c# javascript', 'c# asp.net sql', 'asp.net javascript',
#        'java asp.net javascript', 'mysql sql',
#        'c# .net asp.net javascript', 'ios iphone',
#        'javascript ruby-on-rails ruby', 'python html', 'ios', 'c# php',
#        'php sql', 'jquery css', 'c# asp.net .net', 'objective-c iphone',
#        'python html ruby', 'jquery .net asp.net', 'c# python',
#        'javascript css', 'java python', 'asp.net javascript jquery html',
#        'c# html', 'javascript asp.net', 'javascript jquery ruby-on-rails',
#        'python objective-c', 'c# c++ sql', 'c# mysql', 'c# html css',
#        'jquery html css', 'java c++', 'c++ sql', 'ruby-on-rails css',
#        'iphone ios', 'c# c', 'php ruby-on-rails', 'c# css',
#        'ios objective-c', 'c# c++ c', 'java html', 'html ruby-on-rails',
#        'mysql ruby-on-rails', 'c# .net c++', 'asp.net sql', 'python sql',
#        'php javascript jquery', 'c# jquery', 'c# .net asp.net sql',
#        'php jquery', 'php python', 'php javascript html', '.net c#',
#        'asp.net mysql', 'c# ruby', 'c# asp.net html css',
#        'c# javascript .net asp.net', 'javascript jquery css',
#        'objective-c ruby', 'c++ objective-c', 'java python c',
#        'php sql mysql', '.net iphone', 'c++ html', 'java c',
#        'jquery ruby-on-rails', 'python mysql', 'c# java c',
#        'jquery iphone android', 'java objective-c', '.net android',
#        'c# java ruby', 'c# .net python', 'mysql ruby', 'c objective-c',
#        'php python ruby-on-rails', 'jquery mysql', 'php javascript mysql',
#        'iphone objective-c ios', 'css android', 'php jquery css',
#        'ios objective-c iphone', 'c# android .net', 'c++ mysql c',
#        'c++ iphone', 'php javascript jquery css', '.net javascript',
#        'html ruby', 'c# asp.net jquery', 'c++ ruby',
#        'iphone c objective-c', 'iphone html css', 'c# .net c', 'iphone c',
#        'php sql mysql html', 'objective-c ios', 'c++ mysql',
#        'jquery css html', 'iphone ios objective-c', 'php ruby',
#        'mysql objective-c', 'java sql', 'javascript php',
#        'c# python .net', 'php javascript html css', 'c ruby',
#        'iphone objective-c c', 'c# iphone android', 'php mysql sql',
#        'java jquery', 'c++ html c', 'iphone android', 'c# java .net',
#        'c# iphone', 'ios iphone objective-c', 'mysql c', 'php html css',
#        'python c', 'php iphone objective-c', 'jquery javascript',
#        'c# objective-c', 'javascript css html',
#        'javascript jquery android', '.net c++', 'python css ruby',
#        'c++ android', 'objective-c c', 'php javascript sql',
#        'c# java objective-c', 'java javascript c++', 'html android',
#        'c# .net ruby', 'javascript c++', 'sql android', 'php iphone ios',
#        '.net asp.net sql', 'c# javascript asp.net', 'c# java php',
#        'java iphone objective-c android', 'java python android',
#        'java c# php', 'c# java asp.net', 'android html', 'android ios',
#        'java c android', 'php javascript python',
#        'javascript jquery ruby-on-rails ruby', 'mysql ruby-on-rails ruby',
#        'php c++ c', 'c# php asp.net', 'php mysql html', 'java css',
#        'java objective-c android', 'sql ruby-on-rails ruby',
#        'c# .net c++ c', 'sql mysql ruby-on-rails',
#        'javascript iphone html', 'javascript ruby', 'php iphone',
#        'android css', 'javascript asp.net html',
#        'html ruby-on-rails ruby', 'c# javascript css', 'iphone c++',
#        'php javascript mysql html', 'javascript android', 'android mysql',
#        'c# javascript .net', 'java php android', 'c# asp.net mysql',
#        'php html ios', 'iphone android ruby-on-rails', 'c# ios',
#        'java android c', 'javascript jquery python html',
#        'php jquery html', 'javascript html ruby-on-rails', 'python css',
#        'iphone android html css', 'javascript c# jquery asp.net',
#        'c++ c ios', 'javascript jquery asp.net', '.net mysql',
#        'python android', 'java javascript python', 'android python',
#        'java mysql sql', 'php css', 'javascript .net', 'c# android',
#        'php jquery mysql', 'c# .net mysql', 'c# asp.net html', 'php c',
#        'c# java python c++', 'php jquery html css',
#        'c# javascript jquery asp.net', 'javascript mysql',
#        'javascript jquery iphone', 'javascript php html', 'php .net',
#        'jquery iphone', 'php mysql c', 'javascript iphone html ios',
#        'iphone css', 'c# asp.net android ios', 'php c++', 'c# .net html',
#        'sql ios', 'php javascript python ruby', 'c# java c++ c',
#        'python ios', 'c# .net android', 'java c++ objective-c',
#        'jquery .net', 'c++ java', 'python mysql sql',
#        'javascript jquery iphone ios',
#        'c# javascript jquery asp.net html'], dtype=object)

# %%
import pickle
pickle.dump(similarity,open('similarity.pkl','wb'),-1)

# %%
# open a file, where you stored the pickled data
file = open('similarity.pkl', 'rb')

# dump information to that file
similarity = pickle.load(file)

# %%
pickle.dump(df,open('data.pkl','wb'),-1)
file = open('data.pkl', 'rb')

# dump information to that file
data = pickle.load(file)
data
# Out:
#                                                     Text               Tags
# 0      aspnet site map ha anyon got experi creat sqlb...        sql asp.net
# 1      ad script function to net applic i have a litt...            c# .net
# 2      should i use nest class in thi case i am work ...                c++
# 3      homegrown consumpt of web servic i have been w...               .net
# 4      automat updat version number i would like the ...                 c#
# ...                                                  ...                ...
# 21042  use python subprocess call to invok python scr...             python
# 21043  rail 3 activerecord api build method i am fair...      ruby-on-rails
# 21044  how to move an entir div element up x pixel i ...  javascript jquery
# 21045  get class name from file i have a php file whi...                php
# 21046  backbonej with aspnet mvc in the last few day ...             jquery
#
# [21047 rows x 2 columns]
